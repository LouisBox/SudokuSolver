# %%
board =  [[5,3,0,0,7,0,0,0,0],
          [6,0,0,1,9,5,0,0,0],
          [0,9,8,0,0,0,0,6,0],
          [8,0,0,0,6,0,0,0,3],
          [4,0,0,8,0,3,0,0,1],
          [7,0,0,0,2,0,0,0,6],
          [0,6,0,0,0,0,2,8,0],
          [0,0,0,4,1,9,0,0,5],
          [0,0,0,0,8,0,0,7,9]]


def print_board(board):
    for x in range(len(board)):
        if x%3==0 and x!=0:
            print("- "*13)

        for y in range(len(board[0])):
            if y%3==0 and y!=0:
                print(" | ",end="")

            if y==8:
                print(board[x][y])
            else:
                print(str(board[x][y])+" ",end="")


def find_empty_cell(board):
    for x in range(len(board)):
        for y in range(len(board[0])):
            if board[x][y]==0:
                return (x, y)

    return None

def solve_board(board):
    find = find_empty(board)
    if not find:
        return True
    else:
        row, col = find

    for x in range(1,10):
        if valid(board,x,(row, col)):
            board[row][col]=x

            if solve(board):
                return True

            board[row][col]=0

    return False


def check_valid(board,cc,number): ## CC = CURRENT CELL
    # ROW CHECK
    for x in range(len(board[0])):
        if board[cc[0]][x]==num and cc[1]!=x:
            return False

    for x in range(len(board)):
        if board[x][cc[1]]==num and cc[0]!=x:
            return False

    # BOX CHECK
    box_x = math.floor(cc[1],3)
    box_y = math.floor(cc[0],3)

    for x in range(box_y*3, box_y*3 + 3):
        for y in range(box_x * 3, box_x*3 + 3):
            if board[x][y]==num and (x,y)!=cc:
                return False

    return True

print("Unsolved" + "\n")
print_board(board)
solve_board(board)
print("\n"+"Solved" + "\n")
print_board(board)
# Out:
# Unsolved
#
# 5 3 0  | 0 7 0  | 0 0 0
# 6 0 0  | 1 9 5  | 0 0 0
# 0 9 8  | 0 0 0  | 0 6 0
# - - - - - - - - - - - - -
# 8 0 0  | 0 6 0  | 0 0 3
# 4 0 0  | 8 0 3  | 0 0 1
# 7 0 0  | 0 2 0  | 0 0 6
# - - - - - - - - - - - - -
# 0 6 0  | 0 0 0  | 2 8 0
# 0 0 0  | 4 1 9  | 0 0 5
# 0 0 0  | 0 8 0  | 0 7 9
#
# Solved
#
# 5 3 4  | 6 7 8  | 9 1 2
# 6 7 2  | 1 9 5  | 3 4 8
# 1 9 8  | 3 4 2  | 5 6 7
# - - - - - - - - - - - - -
# 8 5 9  | 7 6 1  | 4 2 3
# 4 2 6  | 8 5 3  | 7 9 1
# 7 1 3  | 9 2 4  | 8 5 6
# - - - - - - - - - - - - -
# 9 6 1  | 5 3 7  | 2 8 4
# 2 8 7  | 4 1 9  | 6 3 5
# 3 4 5  | 2 8 6  | 1 7 9
